# %%
import pandas as pd
offres= pd.read_csv('data/offres.csv')
offres = offres.dropna(subset=['description', 'domaine'])
offres['texte'] = (offres['description'] + ' ' + offres['competences']).str.lower()
x=offres['texte']
y=offres['domaine']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0,stratify=y)
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X_train_vect = vectorizer.fit_transform(X_train)
X_test_vect = vectorizer.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 9
#       5 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0,stratify=y)
#       6 from sklearn.feature_extraction.text import TfidfVectorizer
#       7
#       8 vectorizer = TfidfVectorizer()
# ----> 9 X_train_vect = vectorizer.fit_transform(X_train)
#      10 X_test_vect = vectorizer.transform(X_test)
#
# NameError: name 'X_train' is not defined
